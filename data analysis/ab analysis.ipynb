# %% [markdown]
# <a href="https://colab.research.google.com/github/DrMiracle/Colab-Projects/blob/main/data%20analysis/ab%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1

# %%
import matplotlib.pyplot as plt
import scipy.stats
from scipy import stats
from scipy.stats import norm, t, cauchy

# %%
#гістограма
plt.hist(data, bins=10, density=True, alpha=0.6)

#графік емпіричної функції розподілу
x = sorted(data)
y = [i/len(x) for i in range(len(x))]
plt.plot(x, y)

plt.show()

# %%
#середнє та дисперсія
mean = data.mean()
variance = data.var()

#параметри розподілу
mu = mean
sigma = variance ** 0.5

print("Середнє: ", mu)
print("Середньоквадратичне відхилення: ", sigma)
# Out:
# Середнє:  0.593709090909091
# Середньоквадратичне відхилення:  0.17151881408848982

# %%
#крива нормального розподілу з гістограмою
x = sorted(data)
y = norm.pdf(x, mu, sigma)
plt.hist(data, bins=10, density=True, alpha=0.6)
plt.plot(x, y)

plt.show()

# %%
#параметри Коші
loc, scale = cauchy.fit(data)

#крива Коші з гістограмою
x = sorted(data)
y = cauchy.pdf(x, loc, scale)
plt.hist(data, bins=10, density=True, alpha=0.6)
plt.plot(x, y)

plt.show()

# %% [markdown]
# 2

# %%
from scipy.special import gamma

#Вибірка
x = np.array([50, 75, 125, 250, 300])
alpha = 1.12

mean = np.mean(x)

#Оцінка параметра бета
#(α+1)β = μ
beta = mean / (alpha + 1)
print("Оцінка параметра бета:", beta)
# Out:
# Оцінка параметра бета: 75.47169811320754

# %% [markdown]
# 3

# %%
#Моменти вибірки
mean = np.mean(x)
var = np.var(x)

#Оцінка параметра альфа методом моментів
alpha = (mean ** 2) / var

#Оцінка параметра бета методом моментів
beta = mean / var

print("Оцінка параметра альфа: ", alpha)
print("Оцінка параметра бета: ", beta)
# Out:
# Оцінка параметра альфа:  2.6528497409326426
# Оцінка параметра бета:  0.016580310880829015
